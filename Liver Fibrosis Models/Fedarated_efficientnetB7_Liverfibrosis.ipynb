# %%
# FedAvg with EfficientNet-B7 + Central Test Evaluation + Best-model tracking + Loss curves (Colab-ready)
# Automatically skips missing/corrupted image files during dataset creation and loading.
# Paste this whole cell into Google Colab. Edit BASE_DIR and TEST_DIR to your Drive folders.

# -------------------------
# 0) Mount Drive
# -------------------------
from google.colab import drive
drive.mount('/content/drive')

# -------------------------
# 1) USER SETTINGS (EDIT)
# -------------------------
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/Dataset'   # <-- client folders (each immediate subfolder is a client)
TEST_DIR = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/test'  # <-- central test dataset (ImageFolder-style)
SAVE_PATH = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7.pth'
ROUND_SAVE_PREFIX = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7'

ROUNDS = 7
LOCAL_EPOCHS = 2
BATCH_SIZE = 2
IMG_SIZE = 600
LR = 5e-5
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 2

import torch
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", DEVICE)

# -------------------------
# 2) Libraries
# -------------------------
import os, gc, glob, warnings
from collections import OrderedDict
import copy
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms, models
from PIL import Image, UnidentifiedImageError
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report, confusion_matrix

warnings.filterwarnings("ignore")
sns.set()

# -------------------------
# 3) Helper: allowed extensions and file finding
# -------------------------
ALLOWED_EXT = {'.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff', '.webp', '.ppm', '.pgm'}

def find_images_in_dir(root_dir):
    """Recursively find files with allowed extensions under root_dir."""
    files = []
    for ext in ALLOWED_EXT:
        files.extend(glob.glob(os.path.join(root_dir, '**', f'*{ext}'), recursive=True))
        files.extend(glob.glob(os.path.join(root_dir, '**', f'*{ext.upper()}'), recursive=True))
    files = sorted(set(files))
    return files

# -------------------------
# 4) Robust CustomImageFolder dataset (skips missing/corrupt files)
# -------------------------
class CustomImageFolder(Dataset):
    """
    Similar to torchvision.datasets.ImageFolder but:
    - Builds samples by scanning class subfolders recursively.
    - Filters out missing files at creation time.
    - If an image fails to open at __getitem__, it will attempt a few retries and remove the bad sample.
    """
    def __init__(self, root, transform=None, max_open_tries=3):
        self.root = root
        self.transform = transform
        self.max_open_tries = max_open_tries
        self.classes = []
        self.class_to_idx = {}
        self.samples = []  # list of (filepath, class_idx)
        self._make_dataset()

    def _make_dataset(self):
        entries = sorted(os.listdir(self.root)) if os.path.exists(self.root) else []
        for name in entries:
            p = os.path.join(self.root, name)
            if os.path.isdir(p):
                imgs = find_images_in_dir(p)
                # filter only existing files (defensive)
                valid_imgs = [fp for fp in imgs if os.path.exists(fp)]
                if len(valid_imgs) > 0:
                    idx = len(self.classes)
                    self.classes.append(name)
                    self.class_to_idx[name] = idx
                    for fp in valid_imgs:
                        self.samples.append((fp, idx))
                else:
                    print(f"Warning: class folder '{name}' under '{self.root}' has no valid image files. Skipping class.")
        if len(self.classes) == 0:
            imgs = find_images_in_dir(self.root)
            valid_imgs = [fp for fp in imgs if os.path.exists(fp)]
            if len(valid_imgs) > 0:
                self.classes = ['all']
                self.class_to_idx = {'all': 0}
                for fp in valid_imgs:
                    self.samples.append((fp, 0))
        # Final defensive filter (remove any non-existing paths)
        initial_len = len(self.samples)
        self.samples = [(fp, t) for fp, t in self.samples if os.path.exists(fp)]
        removed = initial_len - len(self.samples)
        if removed > 0:
            print(f"Warning: removed {removed} non-existing files from samples during dataset build.")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        # Defensive: allow retries and remove bad samples on-the-fly
        if len(self.samples) == 0:
            raise IndexError("Dataset contains no valid image samples.")

        # keep an index within bounds
        idx = idx % len(self.samples)
        tries = 0
        while tries < self.max_open_tries:
            path, target = self.samples[idx]
            try:
                img = Image.open(path).convert('RGB')
                if self.transform:
                    img = self.transform(img)
                return img, target
            except (FileNotFoundError, UnidentifiedImageError, OSError) as e:
                # Bad file — log and remove from samples, then try next
                print(f"Warning: failed to open image '{path}'. Removing from dataset. Error: {e}")
                try:
                    # remove the bad sample
                    self.samples.pop(idx)
                except Exception:
                    pass
                if len(self.samples) == 0:
                    raise IndexError("All samples failed to open; dataset is empty after filtering.")
                # do not increment idx — we want to try the next item that took this index
                tries += 1
        # If we exhausted retries, raise
        raise RuntimeError(f"Failed to load a valid image after {self.max_open_tries} attempts.")

# -------------------------
# 5) Transforms (your originals)
# -------------------------
def get_transforms(img_size, train_mode=True):
    if train_mode:
        return transforms.Compose([
            transforms.RandomResizedCrop(img_size, scale=(0.9, 1.0)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=10),
            transforms.RandomAffine(0, translate=(0.05,0.05), scale=(0.95,1.05)),
            transforms.RandomAdjustSharpness(sharpness_factor=1.5, p=0.3),
            transforms.RandomAutocontrast(p=0.3),
            transforms.ToTensor(),
            transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
        ])
    else:
        return transforms.Compose([
            transforms.Resize((img_size, img_size)),
            transforms.ToTensor(),
            transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
        ])

# -------------------------
# 6) Model loader (EfficientNet-B7)
# -------------------------
def load_model_core(num_classes, pretrained=True):
    """
    Load EfficientNet-B7 and replace classifier. Returns model (cpu).
    """
    try:
        weights = models.EfficientNet_B7_Weights.IMAGENET1K_V1 if pretrained else None
        model = models.efficientnet_b7(weights=weights)
    except Exception:
        try:
            model = models.efficientnet_b7(weights="IMAGENET1K_V1")
        except Exception:
            model = models.efficientnet_b7(pretrained=pretrained)
    # replace classifier safely
    try:
        in_features = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(in_features, num_classes)
    except Exception:
        if hasattr(model, 'classifier') and isinstance(model.classifier, nn.Sequential):
            last_linear_idx = None
            for i, layer in enumerate(model.classifier):
                if isinstance(layer, nn.Linear):
                    last_linear_idx = i
            if last_linear_idx is not None:
                in_f = list(model.classifier[last_linear_idx].parameters())[0].shape[1]
                seq = list(model.classifier)
                seq[last_linear_idx] = nn.Linear(in_f, num_classes)
                model.classifier = nn.Sequential(*seq)
    return model

# -------------------------
# 7) ClientTrainer using CustomImageFolder
# -------------------------
class ClientTrainer:
    def __init__(self, client_path, img_size=600, batch_size=2, device='cpu', num_workers=2):
        self.client_path = client_path
        self.img_size = img_size
        self.batch_size = batch_size
        self.device = torch.device(device if torch.cuda.is_available() else 'cpu')
        self.num_workers = num_workers
        self._prepare()

    def _prepare(self):
        self.train_transform = get_transforms(self.img_size, train_mode=True)
        self.eval_transform = get_transforms(self.img_size, train_mode=False)
        self.train_dataset = CustomImageFolder(self.client_path, transform=self.train_transform)
        self.num_samples = len(self.train_dataset)
        self.classes = self.train_dataset.classes
        self.num_classes = len(self.classes)
        if self.num_samples == 0:
            print(f"Warning: client folder '{self.client_path}' has no valid images. This client will be skipped.")
            self.sampler = None
            self.train_loader = None
            return

        labels = [s[1] for s in self.train_dataset.samples]
        class_counts = np.bincount(labels, minlength=max(1, self.num_classes))
        class_counts = np.where(class_counts == 0, 1, class_counts)
        class_weights = 1.0 / class_counts
        samples_weight = [class_weights[l] for l in labels]
        self.sampler = WeightedRandomSampler(samples_weight, num_samples=self.num_samples, replacement=True)
        self.train_loader = DataLoader(self.train_dataset,
                                       batch_size=self.batch_size,
                                       sampler=self.sampler,
                                       num_workers=self.num_workers,
                                       pin_memory=True)

    def local_train(self, base_state_dict, epochs=1, lr=5e-5, weight_decay=1e-4):
        if self.num_samples == 0 or self.train_loader is None:
            return base_state_dict, 0, 0.0

        model = load_model_core(max(self.num_classes, 2), pretrained=False).to(self.device)

        model_state = model.state_dict()
        for k, v in base_state_dict.items():
            if k in model_state and model_state[k].shape == v.shape:
                model_state[k] = v.clone()
        model.load_state_dict(model_state)

        criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
        scaler = torch.cuda.amp.GradScaler()

        model.train()
        total = 0
        running_loss = 0.0
        correct = 0
        for ep in range(epochs):
            gc.collect(); torch.cuda.empty_cache()
            pbar = tqdm(self.train_loader, desc=f"[{os.path.basename(self.client_path)}] epoch {ep+1}/{epochs}")
            for imgs, labels in pbar:
                imgs = imgs.to(self.device)
                labels = labels.to(self.device)
                optimizer.zero_grad()
                with torch.cuda.amp.autocast():
                    outputs = model(imgs)
                    loss = criterion(outputs, labels)
                preds = outputs.argmax(1)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
                running_loss += loss.item() * imgs.size(0)
                correct += (preds == labels).sum().item()
                total += labels.size(0)
                pbar.set_postfix({'loss': running_loss / max(1,total), 'acc': correct / max(1,total)})

        avg_loss = running_loss / max(1, total)
        return model.cpu().state_dict(), self.num_samples, avg_loss

# -------------------------
# 8) Fixed FedAvg aggregation (handles dtype mismatch)
# -------------------------
def fedavg_aggregate(global_state, client_states, client_samples):
    total_samples = sum(client_samples)
    if total_samples == 0:
        return global_state

    new_state = OrderedDict()
    float_keys = []
    for k, v in global_state.items():
        if torch.is_floating_point(v):
            new_state[k] = torch.zeros_like(v, dtype=torch.float32)
            float_keys.append(k)
        else:
            new_state[k] = v.clone()

    for state, n in zip(client_states, client_samples):
        if n == 0: continue
        w = float(n) / float(total_samples)
        for k in float_keys:
            if k in state:
                new_state[k] += state[k].to(dtype=torch.float32) * w

    for k in float_keys:
        orig = global_state[k]
        dtype = orig.dtype
        new_state[k] = new_state[k].to(dtype)

    return new_state

# -------------------------
# 9) Central test evaluator (returns metrics + loss)
# -------------------------
def evaluate_global_model(global_state, test_dir, img_size=600, batch_size=8, device='cuda'):
    # Prepare test dataset (CustomImageFolder)
    test_ds = CustomImageFolder(test_dir, transform=get_transforms(img_size, train_mode=False))
    if len(test_ds) == 0:
        print("No images found in TEST_DIR:", test_dir)
        return None
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

    # Build model and load global state (non-strict load to be safe)
    num_classes = len(test_ds.classes)
    model = load_model_core(num_classes, pretrained=False).to(device)
    # merge states where shapes match
    model_state = model.state_dict()
    for k, v in global_state.items():
        if k in model_state and model_state[k].shape == v.shape:
            model_state[k] = v.clone()
    model.load_state_dict(model_state)

    model.eval()
    y_true = []
    y_pred = []
    total_loss = 0.0
    total_samples = 0
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        if device.type == 'cuda':
            autocast = torch.cuda.amp.autocast
        else:
            from contextlib import nullcontext
            autocast = nullcontext
        with autocast():
            for imgs, labels in tqdm(test_loader, desc="Evaluating on TEST set"):
                imgs = imgs.to(device)
                labels = labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                preds = outputs.argmax(1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())
                total_loss += loss.item() * imgs.size(0)
                total_samples += imgs.size(0)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
    rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
    avg_loss = total_loss / max(1, total_samples)

    metrics = {
        'test_samples': len(test_ds),
        'accuracy': acc,
        'precision_macro': prec,
        'recall_macro': rec,
        'f1_macro': f1,
        'loss': avg_loss,
        'classes': test_ds.classes,
        'y_true': y_true,
        'y_pred': y_pred
    }

    print("\n=== TEST SET RESULTS ===")
    print(f"Test samples      : {len(test_ds)}")
    print(f"Accuracy          : {acc*100:.2f}%")
    print(f"Macro Precision   : {prec:.4f}")
    print(f"Macro Recall      : {rec:.4f}")
    print(f"Macro F1-score    : {f1:.4f}\n")

    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=test_ds.classes, zero_division=0))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,6))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=test_ds.classes, yticklabels=test_ds.classes, cmap='Blues')
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix (Test Set)")
    plt.show()

    return metrics

# -------------------------
# 10) Federated loop (with robust client filtering & diagnostics)
# -------------------------
def run_federated(base_dir, test_dir=None, rounds=5, local_epochs=1, batch_size=2, img_size=600, lr=5e-5, weight_decay=1e-4, device='cuda', save_path=SAVE_PATH, round_save_prefix=ROUND_SAVE_PREFIX):
    device = torch.device(device if torch.cuda.is_available() else 'cpu')
    print("Federated device:", device)

    if not os.path.exists(base_dir):
        raise FileNotFoundError(f"BASE_DIR does not exist: {base_dir}\nDid you mount Drive and edit BASE_DIR correctly?")
    clients = []
    for name in sorted(os.listdir(base_dir)):
        p = os.path.join(base_dir, name)
        if os.path.isdir(p):
            clients.append((name, p))
    if len(clients) == 0:
        raise FileNotFoundError(f"No client subfolders found under BASE_DIR={base_dir}. Directory listing:\n{os.listdir(base_dir)}")

    trainers = []
    for name, path in clients:
        print(f"Scanning client '{name}' at: {path}")
        t = ClientTrainer(path, img_size=img_size, batch_size=batch_size, device=device, num_workers=NUM_WORKERS)
        if t.num_samples == 0:
            print(f" -> Skipping client '{name}' (no valid images found).")
        else:
            print(f" -> Found {t.num_samples} images across {t.num_classes} classes: {t.classes}")
            trainers.append((name, t))

    if len(trainers) == 0:
        sample_listing = []
        for root, dirs, files in os.walk(base_dir):
            sample_listing.extend(files[:10])
            if len(sample_listing) >= 10: break
        raise FileNotFoundError(f"No valid clients with images were found under {base_dir}.\nSample listing (first files found): {sample_listing}\nCheck extensions: {sorted(list(ALLOWED_EXT))}")

    first_client_path = trainers[0][1].client_path
    sample_ds = CustomImageFolder(first_client_path, transform=get_transforms(img_size, train_mode=False))
    num_classes = len(sample_ds.classes) if len(sample_ds.classes)>0 else max(2, trainers[0][1].num_classes)
    print("Global class mapping inferred from first non-empty client:", sample_ds.classes)

    global_model = load_model_core(num_classes, pretrained=True)
    global_state = global_model.state_dict()

    # tracking
    train_loss_per_round = []
    test_loss_per_round = []
    test_f1_per_round = []
    best_f1 = -1.0
    best_state = None
    best_round = -1

    for r in range(1, rounds+1):
        print(f"\n=== Federated Round {r}/{rounds} ===")
        client_states = []
        client_samples = []
        round_train_loss_numer = 0.0
        round_train_samples = 0
        for name, trainer in trainers:
            print(f"\n-> Training client: {name} | samples: {trainer.num_samples}")
            state_dict, n, avg_loss = trainer.local_train(global_state, epochs=local_epochs, lr=lr, weight_decay=weight_decay)
            client_states.append(state_dict)
            client_samples.append(n)
            print(f"Client {name} done. samples={n}, avg_loss={avg_loss:.4f}")
            round_train_loss_numer += avg_loss * n
            round_train_samples += n

        # weighted average train loss for this round
        round_train_loss = round_train_loss_numer / max(1, round_train_samples)
        train_loss_per_round.append(round_train_loss)

        new_global_state = fedavg_aggregate(global_state, client_states, client_samples)
        global_state = new_global_state
        print(f"Round {r} aggregated.")

        round_save = f"{round_save_prefix}_round{r}.pth"
        torch.save({'model_state': global_state, 'num_classes': num_classes}, round_save)
        print("Saved intermediate model:", round_save)

        # Evaluate immediately on test set and keep best model by macro F1
        if test_dir is not None and os.path.exists(test_dir):
            print("\nEvaluating aggregated global model on TEST_DIR...")
            metrics = evaluate_global_model(global_state, test_dir, img_size=img_size, batch_size=max(1, BATCH_SIZE*4), device=device)
            if metrics is not None:
                test_loss_per_round.append(metrics['loss'])
                test_f1_per_round.append(metrics['f1_macro'])
                current_f1 = metrics['f1_macro']
                if current_f1 > best_f1:
                    best_f1 = current_f1
                    best_state = copy.deepcopy(global_state)
                    best_round = r
                    # save best
                    torch.save({'model_state': best_state, 'num_classes': num_classes}, f"{round_save_prefix}_best.pth")
                    print(f"New best model saved (round {r}) with F1={best_f1:.4f}")
        else:
            print("No TEST_DIR provided or it does not exist. Skipping per-round evaluation.")

    # final save
    torch.save({'model_state': global_state, 'num_classes': num_classes}, save_path)
    print("Saved final global model:", save_path)

    # Load best model (if any) and run final evaluation
    if best_state is not None:
        print(f"\nLoading best model from round {best_round} (F1={best_f1:.4f}) for final evaluation...")
        final_metrics = evaluate_global_model(best_state, test_dir, img_size=img_size, batch_size=max(1, BATCH_SIZE*4), device=device)
        print("Final evaluation completed on best model.")
    else:
        print("\nNo best model found (no TEST_DIR or no evaluations ran). Running evaluation on final global state if test_dir exists.")
        if test_dir is not None and os.path.exists(test_dir):
            final_metrics = evaluate_global_model(global_state, test_dir, img_size=img_size, batch_size=max(1, BATCH_SIZE*4), device=device)
        else:
            final_metrics = None

    # Plot loss and F1 curves
    rounds_x = list(range(1, len(train_loss_per_round)+1))
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(rounds_x, train_loss_per_round, marker='o')
    plt.title('Weighted avg client train loss per round')
    plt.xlabel('Round')
    plt.ylabel('Train loss')

    plt.subplot(1,2,2)
    if len(test_loss_per_round) > 0:
        plt.plot(list(range(1, len(test_loss_per_round)+1)), test_loss_per_round, marker='o', label='test loss')
    if len(test_f1_per_round) > 0:
        plt.plot(list(range(1, len(test_f1_per_round)+1)), test_f1_per_round, marker='x', label='test F1')
    plt.title('Test loss and F1 per round')
    plt.xlabel('Round')
    plt.legend()
    plt.tight_layout()
    plt.show()

    return {
        'train_loss_per_round': train_loss_per_round,
        'test_loss_per_round': test_loss_per_round,
        'test_f1_per_round': test_f1_per_round,
        'best_round': best_round,
        'best_f1': best_f1,
        'final_metrics': final_metrics
    }

# -------------------------
# 11) Run
# -------------------------
if __name__ == "__main__":
    run_federated(base_dir=BASE_DIR,
                  test_dir=TEST_DIR,
                  rounds=ROUNDS,
                  local_epochs=LOCAL_EPOCHS,
                  batch_size=BATCH_SIZE,
                  img_size=IMG_SIZE,
                  lr=LR,
                  weight_decay=WEIGHT_DECAY,
                  device='cuda',
                  save_path=SAVE_PATH,
                  round_save_prefix=ROUND_SAVE_PREFIX)
# Out:
# Mounted at /content/drive
# Using device: cuda
# Federated device: cuda
# Scanning client 'Client1' at: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/Dataset/Client1
#  -> Found 2531 images across 5 classes: ['F0', 'F1', 'F2', 'F3', 'F4']
# Scanning client 'Client2' at: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/Dataset/Client2
#  -> Found 2528 images across 5 classes: ['F0', 'F1', 'F2', 'F3', 'F4']
# Global class mapping inferred from first non-empty client: ['F0', 'F1', 'F2', 'F3', 'F4']
# Downloading: "https://download.pytorch.org/models/efficientnet_b7_lukemelas-c5b4e57e.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b7_lukemelas-c5b4e57e.pth
# 100%|██████████| 255M/255M [00:01<00:00, 197MB/s]
# === Federated Round 1/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [07:11<00:00,  2.94it/s, loss=1.26, acc=0.489]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:34<00:00,  3.21it/s, loss=1.08, acc=0.59]
# Client Client1 done. samples=2531, avg_loss=1.0790
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:40<00:00,  3.15it/s, loss=1.23, acc=0.481]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:36<00:00,  3.19it/s, loss=1.07, acc=0.583]
# Client Client2 done. samples=2528, avg_loss=1.0673
# Round 1 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round1.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [02:10<00:00,  1.21it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 75.79%
# Macro Precision   : 0.7489
# Macro Recall      : 0.7008
# Macro F1-score    : 0.6886
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       0.97      0.98      0.98       423
#           F1       0.97      0.63      0.77       172
#           F2       0.50      0.27      0.35       158
#           F3       0.43      0.95      0.59       171
#           F4       0.87      0.67      0.76       340
#
#     accuracy                           0.76      1264
#    macro avg       0.75      0.70      0.69      1264
# weighted avg       0.81      0.76      0.76      1264
# New best model saved (round 1) with F1=0.6886
#
# === Federated Round 2/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [06:38<00:00,  3.17it/s, loss=0.713, acc=0.785]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:39<00:00,  3.17it/s, loss=0.627, acc=0.829]
# Client Client1 done. samples=2531, avg_loss=0.6268
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:37<00:00,  3.18it/s, loss=0.697, acc=0.788]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:36<00:00,  3.19it/s, loss=0.612, acc=0.829]
# Client Client2 done. samples=2528, avg_loss=0.6123
# Round 2 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round2.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:42<00:00,  3.70it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 92.64%
# Macro Precision   : 0.8991
# Macro Recall      : 0.9086
# Macro F1-score    : 0.9029
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      0.99      0.99       423
#           F1       0.87      0.97      0.91       172
#           F2       0.83      0.89      0.86       158
#           F3       0.84      0.78      0.81       171
#           F4       0.96      0.92      0.94       340
#
#     accuracy                           0.93      1264
#    macro avg       0.90      0.91      0.90      1264
# weighted avg       0.93      0.93      0.93      1264
# New best model saved (round 2) with F1=0.9029
#
# === Federated Round 3/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [06:41<00:00,  3.15it/s, loss=0.428, acc=0.922]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:37<00:00,  3.18it/s, loss=0.398, acc=0.936]
# Client Client1 done. samples=2531, avg_loss=0.3982
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:37<00:00,  3.18it/s, loss=0.421, acc=0.925]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:36<00:00,  3.19it/s, loss=0.395, acc=0.934]
# Client Client2 done. samples=2528, avg_loss=0.3949
# Round 3 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round3.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:41<00:00,  3.78it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 95.41%
# Macro Precision   : 0.9353
# Macro Recall      : 0.9420
# Macro F1-score    : 0.9377
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.89      0.99      0.94       172
#           F2       0.87      0.92      0.90       158
#           F3       0.92      0.86      0.89       171
#           F4       0.99      0.94      0.97       340
#
#     accuracy                           0.95      1264
#    macro avg       0.94      0.94      0.94      1264
# weighted avg       0.96      0.95      0.95      1264
# New best model saved (round 3) with F1=0.9377
#
# === Federated Round 4/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [06:42<00:00,  3.14it/s, loss=0.321, acc=0.971]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:37<00:00,  3.19it/s, loss=0.323, acc=0.968]
# Client Client1 done. samples=2531, avg_loss=0.3227
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:37<00:00,  3.18it/s, loss=0.336, acc=0.963]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:37<00:00,  3.18it/s, loss=0.32, acc=0.969]
# Client Client2 done. samples=2528, avg_loss=0.3199
# Round 4 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round4.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:42<00:00,  3.76it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 98.73%
# Macro Precision   : 0.9833
# Macro Recall      : 0.9823
# Macro F1-score    : 0.9826
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.98      0.98      0.98       172
#           F2       0.96      0.99      0.97       158
#           F3       0.99      0.95      0.97       171
#           F4       0.99      0.99      0.99       340
#
#     accuracy                           0.99      1264
#    macro avg       0.98      0.98      0.98      1264
# weighted avg       0.99      0.99      0.99      1264
# New best model saved (round 4) with F1=0.9826
#
# === Federated Round 5/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [06:42<00:00,  3.14it/s, loss=0.286, acc=0.982]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:37<00:00,  3.18it/s, loss=0.289, acc=0.98]
# Client Client1 done. samples=2531, avg_loss=0.2886
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:36<00:00,  3.18it/s, loss=0.289, acc=0.983]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:36<00:00,  3.19it/s, loss=0.291, acc=0.98]
# Client Client2 done. samples=2528, avg_loss=0.2911
# Round 5 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round5.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:42<00:00,  3.76it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 98.42%
# Macro Precision   : 0.9771
# Macro Recall      : 0.9785
# Macro F1-score    : 0.9777
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.99      0.99      0.99       172
#           F2       0.93      0.97      0.95       158
#           F3       0.97      0.94      0.96       171
#           F4       0.99      0.99      0.99       340
#
#     accuracy                           0.98      1264
#    macro avg       0.98      0.98      0.98      1264
# weighted avg       0.98      0.98      0.98      1264
# === Federated Round 6/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [06:37<00:00,  3.18it/s, loss=0.273, acc=0.987]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:36<00:00,  3.19it/s, loss=0.269, acc=0.987]
# Client Client1 done. samples=2531, avg_loss=0.2692
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:35<00:00,  3.19it/s, loss=0.27, acc=0.984]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:35<00:00,  3.20it/s, loss=0.279, acc=0.98]
# Client Client2 done. samples=2528, avg_loss=0.2789
# Round 6 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round6.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:41<00:00,  3.79it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 98.81%
# Macro Precision   : 0.9844
# Macro Recall      : 0.9832
# Macro F1-score    : 0.9838
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.99      0.99      0.99       172
#           F2       0.97      0.97      0.97       158
#           F3       0.98      0.96      0.97       171
#           F4       0.99      0.99      0.99       340
#
#     accuracy                           0.99      1264
#    macro avg       0.98      0.98      0.98      1264
# weighted avg       0.99      0.99      0.99      1264
# New best model saved (round 6) with F1=0.9838
#
# === Federated Round 7/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 1266/1266 [06:39<00:00,  3.17it/s, loss=0.264, acc=0.985]
# [Client1] epoch 2/2: 100%|██████████| 1266/1266 [06:38<00:00,  3.18it/s, loss=0.264, acc=0.986]
# Client Client1 done. samples=2531, avg_loss=0.2644
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 1264/1264 [06:37<00:00,  3.18it/s, loss=0.27, acc=0.986]
# [Client2] epoch 2/2: 100%|██████████| 1264/1264 [06:36<00:00,  3.19it/s, loss=0.268, acc=0.986]
# Client Client2 done. samples=2528, avg_loss=0.2679
# Round 7 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7_round7.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:41<00:00,  3.79it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 98.50%
# Macro Precision   : 0.9797
# Macro Recall      : 0.9788
# Macro F1-score    : 0.9789
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.99      0.99      0.99       172
#           F2       0.93      0.99      0.96       158
#           F3       0.99      0.92      0.95       171
#           F4       0.99      0.99      0.99       340
#
#     accuracy                           0.98      1264
#    macro avg       0.98      0.98      0.98      1264
# weighted avg       0.99      0.98      0.98      1264
# Saved final global model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_efficientnetb7.pth
#
# Loading best model from round 6 (F1=0.9838) for final evaluation...
# Evaluating on TEST set: 100%|██████████| 158/158 [00:40<00:00,  3.86it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 98.81%
# Macro Precision   : 0.9844
# Macro Recall      : 0.9832
# Macro F1-score    : 0.9838
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.99      0.99      0.99       172
#           F2       0.97      0.97      0.97       158
#           F3       0.98      0.96      0.97       171
#           F4       0.99      0.99      0.99       340
#
#     accuracy                           0.99      1264
#    macro avg       0.98      0.98      0.98      1264
# weighted avg       0.99      0.99      0.99      1264
# Final evaluation completed on best model.
