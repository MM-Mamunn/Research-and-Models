# %%
# FedAvg with VGG-19 + Central Test Evaluation + Best-model tracking + Loss curves (Colab-ready)
# Automatically skips missing/corrupted image files during dataset creation and loading.
# Paste this whole cell into Google Colab. Edit BASE_DIR and TEST_DIR to your Drive folders.

# -------------------------
# 0) Mount Drive
# -------------------------
from google.colab import drive
drive.mount('/content/drive')

# -------------------------
# 1) USER SETTINGS (EDIT)
# -------------------------
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/Dataset'   # <-- client folders (each immediate subfolder is a client)
TEST_DIR = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/test'  # <-- central test dataset (ImageFolder-style)
SAVE_PATH = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19.pth'
ROUND_SAVE_PREFIX = '/content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19'

ROUNDS = 7
LOCAL_EPOCHS = 2
BATCH_SIZE = 8        # increased default for stability; adjust as needed
IMG_SIZE = 224        # VGG-19 typical input size
LR = 5e-5
WEIGHT_DECAY = 1e-4
NUM_WORKERS = 2

import torch
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", DEVICE)

# -------------------------
# 2) Libraries
# -------------------------
import os, gc, glob, warnings
from collections import OrderedDict
import copy
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms, models
from PIL import Image, UnidentifiedImageError
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report, confusion_matrix

warnings.filterwarnings("ignore")
sns.set()

# -------------------------
# 3) Helper: allowed extensions and file finding
# -------------------------
ALLOWED_EXT = {'.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff', '.webp', '.ppm', '.pgm'}

def find_images_in_dir(root_dir):
    """Recursively find files with allowed extensions under root_dir."""
    files = []
    for ext in ALLOWED_EXT:
        files.extend(glob.glob(os.path.join(root_dir, '**', f'*{ext}'), recursive=True))
        files.extend(glob.glob(os.path.join(root_dir, '**', f'*{ext.upper()}'), recursive=True))
    files = sorted(set(files))
    return files

# -------------------------
# 4) Robust CustomImageFolder dataset (skips missing/corrupt files)
# -------------------------
class CustomImageFolder(Dataset):
    """
    Similar to torchvision.datasets.ImageFolder but:
    - Builds samples by scanning class subfolders recursively.
    - Filters out missing files at creation time.
    - If an image fails to open at __getitem__, it will attempt a few retries and remove the bad sample.
    """
    def __init__(self, root, transform=None, max_open_tries=3):
        self.root = root
        self.transform = transform
        self.max_open_tries = max_open_tries
        self.classes = []
        self.class_to_idx = {}
        self.samples = []  # list of (filepath, class_idx)
        self._make_dataset()

    def _make_dataset(self):
        entries = sorted(os.listdir(self.root)) if os.path.exists(self.root) else []
        for name in entries:
            p = os.path.join(self.root, name)
            if os.path.isdir(p):
                imgs = find_images_in_dir(p)
                # filter only existing files (defensive)
                valid_imgs = [fp for fp in imgs if os.path.exists(fp)]
                if len(valid_imgs) > 0:
                    idx = len(self.classes)
                    self.classes.append(name)
                    self.class_to_idx[name] = idx
                    for fp in valid_imgs:
                        self.samples.append((fp, idx))
                else:
                    print(f"Warning: class folder '{name}' under '{self.root}' has no valid image files. Skipping class.")
        if len(self.classes) == 0:
            imgs = find_images_in_dir(self.root)
            valid_imgs = [fp for fp in imgs if os.path.exists(fp)]
            if len(valid_imgs) > 0:
                self.classes = ['all']
                self.class_to_idx = {'all': 0}
                for fp in valid_imgs:
                    self.samples.append((fp, 0))
        # Final defensive filter (remove any non-existing paths)
        initial_len = len(self.samples)
        self.samples = [(fp, t) for fp, t in self.samples if os.path.exists(fp)]
        removed = initial_len - len(self.samples)
        if removed > 0:
            print(f"Warning: removed {removed} non-existing files from samples during dataset build.")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        # Defensive: allow retries and remove bad samples on-the-fly
        if len(self.samples) == 0:
            raise IndexError("Dataset contains no valid image samples.")

        # keep an index within bounds
        idx = idx % len(self.samples)
        tries = 0
        while tries < self.max_open_tries:
            path, target = self.samples[idx]
            try:
                img = Image.open(path).convert('RGB')
                if self.transform:
                    img = self.transform(img)
                return img, target
            except (FileNotFoundError, UnidentifiedImageError, OSError) as e:
                # Bad file — log and remove from samples, then try next
                print(f"Warning: failed to open image '{path}'. Removing from dataset. Error: {e}")
                try:
                    # remove the bad sample
                    self.samples.pop(idx)
                except Exception:
                    pass
                if len(self.samples) == 0:
                    raise IndexError("All samples failed to open; dataset is empty after filtering.")
                # do not increment idx — we want to try the next item that took this index
                tries += 1
        # If we exhausted retries, raise
        raise RuntimeError(f"Failed to load a valid image after {self.max_open_tries} attempts.")

# -------------------------
# 5) Transforms (VGG-19 appropriate preprocessing)
# -------------------------
def get_transforms(img_size, train_mode=True):
    # For VGG-19 standard preprocessing:
    # train: RandomResizedCrop(img_size) + random flip/rotation etc.
    # eval: Resize(256) + CenterCrop(img_size)
    if train_mode:
        return transforms.Compose([
            transforms.RandomResizedCrop(img_size, scale=(0.8, 1.0)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=10),
            transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.02),
            transforms.ToTensor(),
            transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
        ])
    else:
        return transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(img_size),
            transforms.ToTensor(),
            transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
        ])

# -------------------------
# 6) Model loader (VGG-19)
# -------------------------
def load_model_core(num_classes, pretrained=True):
    """
    Load VGG-19 and replace final classifier Linear to match num_classes.
    Returns model (cpu).
    """
    try:
        weights = models.VGG19_Weights.IMAGENET1K_V1 if pretrained else None
        model = models.vgg19(weights=weights)
    except Exception:
        try:
            model = models.vgg19(weights="IMAGENET1K_V1")
        except Exception:
            model = models.vgg19(pretrained=pretrained)

    # Replace last linear layer in classifier safely
    try:
        if hasattr(model, 'classifier') and isinstance(model.classifier, nn.Sequential):
            # find last Linear layer index
            last_linear_idx = None
            for i, layer in enumerate(model.classifier):
                if isinstance(layer, nn.Linear):
                    last_linear_idx = i
            if last_linear_idx is not None:
                in_f = model.classifier[last_linear_idx].in_features
                seq = list(model.classifier)
                seq[last_linear_idx] = nn.Linear(in_f, num_classes)
                model.classifier = nn.Sequential(*seq)
        else:
            # fallback: overwrite classifier with a common head
            model.classifier = nn.Sequential(
                nn.Linear(25088, 4096),
                nn.ReLU(True),
                nn.Dropout(),
                nn.Linear(4096, 4096),
                nn.ReLU(True),
                nn.Dropout(),
                nn.Linear(4096, num_classes)
            )
    except Exception as e:
        print("Warning while replacing classifier:", e)
    return model

# -------------------------
# 7) ClientTrainer using CustomImageFolder
# -------------------------
class ClientTrainer:
    def __init__(self, client_path, img_size=224, batch_size=8, device='cpu', num_workers=2):
        self.client_path = client_path
        self.img_size = img_size
        self.batch_size = batch_size
        self.device = torch.device(device if torch.cuda.is_available() else 'cpu')
        self.num_workers = num_workers
        self._prepare()

    def _prepare(self):
        # Each client gets the proper VGG transforms (train / eval)
        self.train_transform = get_transforms(self.img_size, train_mode=True)
        self.eval_transform = get_transforms(self.img_size, train_mode=False)
        self.train_dataset = CustomImageFolder(self.client_path, transform=self.train_transform)
        self.num_samples = len(self.train_dataset)
        self.classes = self.train_dataset.classes
        self.num_classes = len(self.classes)
        if self.num_samples == 0:
            print(f"Warning: client folder '{self.client_path}' has no valid images. This client will be skipped.")
            self.sampler = None
            self.train_loader = None
            return

        labels = [s[1] for s in self.train_dataset.samples]
        class_counts = np.bincount(labels, minlength=max(1, self.num_classes))
        class_counts = np.where(class_counts == 0, 1, class_counts)
        class_weights = 1.0 / class_counts
        samples_weight = [class_weights[l] for l in labels]
        self.sampler = WeightedRandomSampler(samples_weight, num_samples=self.num_samples, replacement=True)
        self.train_loader = DataLoader(self.train_dataset,
                                       batch_size=self.batch_size,
                                       sampler=self.sampler,
                                       num_workers=self.num_workers,
                                       pin_memory=True)

    def local_train(self, base_state_dict, epochs=1, lr=5e-5, weight_decay=1e-4):
        if self.num_samples == 0 or self.train_loader is None:
            return base_state_dict, 0, 0.0

        model = load_model_core(max(self.num_classes, 2), pretrained=False).to(self.device)

        model_state = model.state_dict()
        for k, v in base_state_dict.items():
            if k in model_state and model_state[k].shape == v.shape:
                model_state[k] = v.clone()
        model.load_state_dict(model_state)

        criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
        scaler = torch.cuda.amp.GradScaler()

        model.train()
        total = 0
        running_loss = 0.0
        correct = 0
        for ep in range(epochs):
            gc.collect(); torch.cuda.empty_cache()
            pbar = tqdm(self.train_loader, desc=f"[{os.path.basename(self.client_path)}] epoch {ep+1}/{epochs}")
            for imgs, labels in pbar:
                imgs = imgs.to(self.device)
                labels = labels.to(self.device)
                optimizer.zero_grad()
                with torch.cuda.amp.autocast():
                    outputs = model(imgs)
                    loss = criterion(outputs, labels)
                preds = outputs.argmax(1)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
                running_loss += loss.item() * imgs.size(0)
                correct += (preds == labels).sum().item()
                total += labels.size(0)
                pbar.set_postfix({'loss': running_loss / max(1,total), 'acc': correct / max(1,total)})

        avg_loss = running_loss / max(1, total)
        return model.cpu().state_dict(), self.num_samples, avg_loss

# -------------------------
# 8) Fixed FedAvg aggregation (handles dtype mismatch)
# -------------------------
def fedavg_aggregate(global_state, client_states, client_samples):
    total_samples = sum(client_samples)
    if total_samples == 0:
        return global_state

    new_state = OrderedDict()
    float_keys = []
    for k, v in global_state.items():
        if torch.is_floating_point(v):
            new_state[k] = torch.zeros_like(v, dtype=torch.float32)
            float_keys.append(k)
        else:
            new_state[k] = v.clone()

    for state, n in zip(client_states, client_samples):
        if n == 0: continue
        w = float(n) / float(total_samples)
        for k in float_keys:
            if k in state:
                new_state[k] += state[k].to(dtype=torch.float32) * w

    for k in float_keys:
        orig = global_state[k]
        dtype = orig.dtype
        new_state[k] = new_state[k].to(dtype)

    return new_state

# -------------------------
# 9) Central test evaluator (returns metrics + loss)
# -------------------------
def evaluate_global_model(global_state, test_dir, img_size=224, batch_size=8, device='cuda'):
    # Prepare test dataset (CustomImageFolder)
    test_ds = CustomImageFolder(test_dir, transform=get_transforms(img_size, train_mode=False))
    if len(test_ds) == 0:
        print("No images found in TEST_DIR:", test_dir)
        return None
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

    # Build model and load global state (non-strict load to be safe)
    num_classes = len(test_ds.classes)
    model = load_model_core(num_classes, pretrained=False).to(device)
    # merge states where shapes match
    model_state = model.state_dict()
    for k, v in global_state.items():
        if k in model_state and model_state[k].shape == v.shape:
            model_state[k] = v.clone()
    model.load_state_dict(model_state)

    model.eval()
    y_true = []
    y_pred = []
    total_loss = 0.0
    total_samples = 0
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        if device.type == 'cuda':
            autocast = torch.cuda.amp.autocast
        else:
            from contextlib import nullcontext
            autocast = nullcontext
        with autocast():
            for imgs, labels in tqdm(test_loader, desc="Evaluating on TEST set"):
                imgs = imgs.to(device)
                labels = labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                preds = outputs.argmax(1)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(preds.cpu().numpy())
                total_loss += loss.item() * imgs.size(0)
                total_samples += imgs.size(0)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
    rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
    avg_loss = total_loss / max(1, total_samples)

    metrics = {
        'test_samples': len(test_ds),
        'accuracy': acc,
        'precision_macro': prec,
        'recall_macro': rec,
        'f1_macro': f1,
        'loss': avg_loss,
        'classes': test_ds.classes,
        'y_true': y_true,
        'y_pred': y_pred
    }

    print("\n=== TEST SET RESULTS ===")
    print(f"Test samples      : {len(test_ds)}")
    print(f"Accuracy          : {acc*100:.2f}%")
    print(f"Macro Precision   : {prec:.4f}")
    print(f"Macro Recall      : {rec:.4f}")
    print(f"Macro F1-score    : {f1:.4f}\n")

    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=test_ds.classes, zero_division=0))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,6))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=test_ds.classes, yticklabels=test_ds.classes, cmap='Blues')
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix (Test Set)")
    plt.show()

    return metrics

# -------------------------
# 10) Federated loop (with robust client filtering & diagnostics)
# -------------------------
def run_federated(base_dir, test_dir=None, rounds=5, local_epochs=1, batch_size=8, img_size=224, lr=5e-5, weight_decay=1e-4, device='cuda', save_path=SAVE_PATH, round_save_prefix=ROUND_SAVE_PREFIX):
    device = torch.device(device if torch.cuda.is_available() else 'cpu')
    print("Federated device:", device)

    if not os.path.exists(base_dir):
        raise FileNotFoundError(f"BASE_DIR does not exist: {base_dir}\nDid you mount Drive and edit BASE_DIR correctly?")
    clients = []
    for name in sorted(os.listdir(base_dir)):
        p = os.path.join(base_dir, name)
        if os.path.isdir(p):
            clients.append((name, p))
    if len(clients) == 0:
        raise FileNotFoundError(f"No client subfolders found under BASE_DIR={base_dir}. Directory listing:\n{os.listdir(base_dir)}")

    trainers = []
    for name, path in clients:
        print(f"Scanning client '{name}' at: {path}")
        t = ClientTrainer(path, img_size=img_size, batch_size=batch_size, device=device, num_workers=NUM_WORKERS)
        if t.num_samples == 0:
            print(f" -> Skipping client '{name}' (no valid images found).")
        else:
            print(f" -> Found {t.num_samples} images across {t.num_classes} classes: {t.classes}")
            trainers.append((name, t))

    if len(trainers) == 0:
        sample_listing = []
        for root, dirs, files in os.walk(base_dir):
            sample_listing.extend(files[:10])
            if len(sample_listing) >= 10: break
        raise FileNotFoundError(f"No valid clients with images were found under {base_dir}.\nSample listing (first files found): {sample_listing}\nCheck extensions: {sorted(list(ALLOWED_EXT))}")

    first_client_path = trainers[0][1].client_path
    sample_ds = CustomImageFolder(first_client_path, transform=get_transforms(img_size, train_mode=False))
    num_classes = len(sample_ds.classes) if len(sample_ds.classes)>0 else max(2, trainers[0][1].num_classes)
    print("Global class mapping inferred from first non-empty client:", sample_ds.classes)

    global_model = load_model_core(num_classes, pretrained=True)
    global_state = global_model.state_dict()

    # tracking
    train_loss_per_round = []
    test_loss_per_round = []
    test_f1_per_round = []
    best_f1 = -1.0
    best_state = None
    best_round = -1

    for r in range(1, rounds+1):
        print(f"\n=== Federated Round {r}/{rounds} ===")
        client_states = []
        client_samples = []
        round_train_loss_numer = 0.0
        round_train_samples = 0
        for name, trainer in trainers:
            print(f"\n-> Training client: {name} | samples: {trainer.num_samples}")
            state_dict, n, avg_loss = trainer.local_train(global_state, epochs=local_epochs, lr=lr, weight_decay=weight_decay)
            client_states.append(state_dict)
            client_samples.append(n)
            print(f"Client {name} done. samples={n}, avg_loss={avg_loss:.4f}")
            round_train_loss_numer += avg_loss * n
            round_train_samples += n

        # weighted average train loss for this round
        round_train_loss = round_train_loss_numer / max(1, round_train_samples)
        train_loss_per_round.append(round_train_loss)

        new_global_state = fedavg_aggregate(global_state, client_states, client_samples)
        global_state = new_global_state
        print(f"Round {r} aggregated.")

        round_save = f"{round_save_prefix}_round{r}.pth"
        torch.save({'model_state': global_state, 'num_classes': num_classes}, round_save)
        print("Saved intermediate model:", round_save)

        # Evaluate immediately on test set and keep best model by macro F1
        if test_dir is not None and os.path.exists(test_dir):
            print("\nEvaluating aggregated global model on TEST_DIR...")
            metrics = evaluate_global_model(global_state, test_dir, img_size=img_size, batch_size=max(1, BATCH_SIZE*2), device=device)
            if metrics is not None:
                test_loss_per_round.append(metrics['loss'])
                test_f1_per_round.append(metrics['f1_macro'])
                current_f1 = metrics['f1_macro']
                if current_f1 > best_f1:
                    best_f1 = current_f1
                    best_state = copy.deepcopy(global_state)
                    best_round = r
                    # save best
                    torch.save({'model_state': best_state, 'num_classes': num_classes}, f"{round_save_prefix}_best.pth")
                    print(f"New best model saved (round {r}) with F1={best_f1:.4f}")
        else:
            print("No TEST_DIR provided or it does not exist. Skipping per-round evaluation.")

    # final save
    torch.save({'model_state': global_state, 'num_classes': num_classes}, save_path)
    print("Saved final global model:", save_path)

    # Load best model (if any) and run final evaluation
    if best_state is not None:
        print(f"\nLoading best model from round {best_round} (F1={best_f1:.4f}) for final evaluation...")
        final_metrics = evaluate_global_model(best_state, test_dir, img_size=img_size, batch_size=max(1, BATCH_SIZE*2), device=device)
        print("Final evaluation completed on best model.")
    else:
        print("\nNo best model found (no TEST_DIR or no evaluations ran). Running evaluation on final global state if test_dir exists.")
        if test_dir is not None and os.path.exists(test_dir):
            final_metrics = evaluate_global_model(global_state, test_dir, img_size=img_size, batch_size=max(1, BATCH_SIZE*2), device=device)
        else:
            final_metrics = None

    # Plot loss and F1 curves
    rounds_x = list(range(1, len(train_loss_per_round)+1))
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(rounds_x, train_loss_per_round, marker='o')
    plt.title('Weighted avg client train loss per round')
    plt.xlabel('Round')
    plt.ylabel('Train loss')

    plt.subplot(1,2,2)
    if len(test_loss_per_round) > 0:
        plt.plot(list(range(1, len(test_loss_per_round)+1)), test_loss_per_round, marker='o', label='test loss')
    if len(test_f1_per_round) > 0:
        plt.plot(list(range(1, len(test_f1_per_round)+1)), test_f1_per_round, marker='x', label='test F1')
    plt.title('Test loss and F1 per round')
    plt.xlabel('Round')
    plt.legend()
    plt.tight_layout()
    plt.show()

    return {
        'train_loss_per_round': train_loss_per_round,
        'test_loss_per_round': test_loss_per_round,
        'test_f1_per_round': test_f1_per_round,
        'best_round': best_round,
        'best_f1': best_f1,
        'final_metrics': final_metrics
    }

# -------------------------
# 11) Run
# -------------------------
if __name__ == "__main__":
    run_federated(base_dir=BASE_DIR,
                  test_dir=TEST_DIR,
                  rounds=ROUNDS,
                  local_epochs=LOCAL_EPOCHS,
                  batch_size=BATCH_SIZE,
                  img_size=IMG_SIZE,
                  lr=LR,
                  weight_decay=WEIGHT_DECAY,
                  device='cuda',
                  save_path=SAVE_PATH,
                  round_save_prefix=ROUND_SAVE_PREFIX)
# Out:
# Mounted at /content/drive
# Using device: cuda
# Federated device: cuda
# Scanning client 'Client1' at: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/Dataset/Client1
#  -> Found 2531 images across 5 classes: ['F0', 'F1', 'F2', 'F3', 'F4']
# Scanning client 'Client2' at: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/Dataset/Client2
#  -> Found 2528 images across 5 classes: ['F0', 'F1', 'F2', 'F3', 'F4']
# Global class mapping inferred from first non-empty client: ['F0', 'F1', 'F2', 'F3', 'F4']
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:06<00:00, 90.2MB/s]
# === Federated Round 1/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [04:33<00:00,  1.16it/s, loss=1.24, acc=0.462]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [02:00<00:00,  2.63it/s, loss=1.14, acc=0.524]
# Client Client1 done. samples=2531, avg_loss=1.1361
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [04:57<00:00,  1.06it/s, loss=1.2, acc=0.476]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [01:56<00:00,  2.71it/s, loss=1.11, acc=0.521]
# Client Client2 done. samples=2528, avg_loss=1.1145
# Round 1 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round1.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [02:50<00:00,  2.16s/it]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 62.66%
# Macro Precision   : 0.6010
# Macro Recall      : 0.5639
# Macro F1-score    : 0.5485
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       0.89      0.99      0.94       423
#           F1       0.46      0.41      0.43       172
#           F2       0.29      0.67      0.41       158
#           F3       0.57      0.35      0.43       171
#           F4       0.79      0.41      0.54       340
#
#     accuracy                           0.63      1264
#    macro avg       0.60      0.56      0.55      1264
# weighted avg       0.69      0.63      0.63      1264
# New best model saved (round 1) with F1=0.5485
#
# === Federated Round 2/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [01:06<00:00,  4.78it/s, loss=0.934, acc=0.64]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [00:55<00:00,  5.67it/s, loss=0.88, acc=0.674]
# Client Client1 done. samples=2531, avg_loss=0.8795
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [01:15<00:00,  4.20it/s, loss=0.932, acc=0.63]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [00:56<00:00,  5.61it/s, loss=0.889, acc=0.669]
# Client Client2 done. samples=2528, avg_loss=0.8886
# Round 2 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round2.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:13<00:00,  5.68it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 75.24%
# Macro Precision   : 0.7020
# Macro Recall      : 0.7031
# Macro F1-score    : 0.6931
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       0.94      1.00      0.97       423
#           F1       0.61      0.71      0.66       172
#           F2       0.41      0.56      0.47       158
#           F3       0.62      0.63      0.62       171
#           F4       0.93      0.62      0.74       340
#
#     accuracy                           0.75      1264
#    macro avg       0.70      0.70      0.69      1264
# weighted avg       0.78      0.75      0.76      1264
# New best model saved (round 2) with F1=0.6931
#
# === Federated Round 3/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [01:03<00:00,  5.00it/s, loss=0.707, acc=0.778]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [00:44<00:00,  7.08it/s, loss=0.674, acc=0.793]
# Client Client1 done. samples=2531, avg_loss=0.6741
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [00:48<00:00,  6.46it/s, loss=0.722, acc=0.769]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [00:47<00:00,  6.61it/s, loss=0.696, acc=0.783]
# Client Client2 done. samples=2528, avg_loss=0.6959
# Round 3 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round3.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:13<00:00,  5.82it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 86.16%
# Macro Precision   : 0.8207
# Macro Recall      : 0.8285
# Macro F1-score    : 0.8171
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       0.97      1.00      0.98       423
#           F1       0.70      0.88      0.78       172
#           F2       0.73      0.58      0.64       158
#           F3       0.72      0.88      0.79       171
#           F4       0.99      0.80      0.88       340
#
#     accuracy                           0.86      1264
#    macro avg       0.82      0.83      0.82      1264
# weighted avg       0.87      0.86      0.86      1264
# New best model saved (round 3) with F1=0.8171
#
# === Federated Round 4/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [00:58<00:00,  5.43it/s, loss=0.58, acc=0.847]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [00:43<00:00,  7.27it/s, loss=0.545, acc=0.864]
# Client Client1 done. samples=2531, avg_loss=0.5448
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [00:45<00:00,  6.89it/s, loss=0.58, acc=0.843]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [00:44<00:00,  7.11it/s, loss=0.55, acc=0.862]
# Client Client2 done. samples=2528, avg_loss=0.5496
# Round 4 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round4.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:13<00:00,  5.91it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 89.79%
# Macro Precision   : 0.8697
# Macro Recall      : 0.8866
# Macro F1-score    : 0.8737
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       0.98      1.00      0.99       423
#           F1       0.81      0.92      0.86       172
#           F2       0.71      0.88      0.78       158
#           F3       0.87      0.83      0.85       171
#           F4       0.99      0.81      0.89       340
#
#     accuracy                           0.90      1264
#    macro avg       0.87      0.89      0.87      1264
# weighted avg       0.91      0.90      0.90      1264
# New best model saved (round 4) with F1=0.8737
#
# === Federated Round 5/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [00:58<00:00,  5.42it/s, loss=0.464, acc=0.898]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [00:44<00:00,  7.06it/s, loss=0.446, acc=0.91]
# Client Client1 done. samples=2531, avg_loss=0.4462
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [00:42<00:00,  7.35it/s, loss=0.46, acc=0.902]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [00:42<00:00,  7.43it/s, loss=0.441, acc=0.914]
# Client Client2 done. samples=2528, avg_loss=0.4412
# Round 5 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round5.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:13<00:00,  6.06it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 94.07%
# Macro Precision   : 0.9166
# Macro Recall      : 0.9267
# Macro F1-score    : 0.9211
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.90      0.97      0.93       172
#           F2       0.85      0.87      0.86       158
#           F3       0.86      0.88      0.87       171
#           F4       0.98      0.92      0.95       340
#
#     accuracy                           0.94      1264
#    macro avg       0.92      0.93      0.92      1264
# weighted avg       0.94      0.94      0.94      1264
# New best model saved (round 5) with F1=0.9211
#
# === Federated Round 6/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [00:58<00:00,  5.45it/s, loss=0.395, acc=0.933]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [00:42<00:00,  7.41it/s, loss=0.393, acc=0.935]
# Client Client1 done. samples=2531, avg_loss=0.3935
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [00:42<00:00,  7.38it/s, loss=0.402, acc=0.93]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [00:42<00:00,  7.39it/s, loss=0.389, acc=0.938]
# Client Client2 done. samples=2528, avg_loss=0.3886
# Round 6 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round6.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:12<00:00,  6.08it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 95.41%
# Macro Precision   : 0.9360
# Macro Recall      : 0.9457
# Macro F1-score    : 0.9400
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.89      0.99      0.94       172
#           F2       0.91      0.88      0.89       158
#           F3       0.89      0.93      0.91       171
#           F4       0.99      0.93      0.96       340
#
#     accuracy                           0.95      1264
#    macro avg       0.94      0.95      0.94      1264
# weighted avg       0.96      0.95      0.95      1264
# New best model saved (round 6) with F1=0.9400
#
# === Federated Round 7/7 ===
#
# -> Training client: Client1 | samples: 2531
# [Client1] epoch 1/2: 100%|██████████| 317/317 [00:57<00:00,  5.47it/s, loss=0.352, acc=0.951]
# [Client1] epoch 2/2: 100%|██████████| 317/317 [00:42<00:00,  7.39it/s, loss=0.354, acc=0.951]
# Client Client1 done. samples=2531, avg_loss=0.3540
#
# -> Training client: Client2 | samples: 2528
# [Client2] epoch 1/2: 100%|██████████| 316/316 [00:43<00:00,  7.20it/s, loss=0.357, acc=0.954]
# [Client2] epoch 2/2: 100%|██████████| 316/316 [00:42<00:00,  7.41it/s, loss=0.354, acc=0.952]
# Client Client2 done. samples=2528, avg_loss=0.3538
# Round 7 aggregated.
# Saved intermediate model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19_round7.pth
#
# Evaluating aggregated global model on TEST_DIR...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:13<00:00,  5.73it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 96.84%
# Macro Precision   : 0.9564
# Macro Recall      : 0.9626
# Macro F1-score    : 0.9593
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.95      0.98      0.97       172
#           F2       0.92      0.96      0.94       158
#           F3       0.93      0.92      0.93       171
#           F4       0.98      0.95      0.97       340
#
#     accuracy                           0.97      1264
#    macro avg       0.96      0.96      0.96      1264
# weighted avg       0.97      0.97      0.97      1264
# New best model saved (round 7) with F1=0.9593
# Saved final global model: /content/drive/MyDrive/Colab Notebooks/liver_fibrosis/global_vgg19.pth
#
# Loading best model from round 7 (F1=0.9593) for final evaluation...
# Evaluating on TEST set: 100%|██████████| 79/79 [00:27<00:00,  2.83it/s]
# === TEST SET RESULTS ===
# Test samples      : 1264
# Accuracy          : 96.84%
# Macro Precision   : 0.9564
# Macro Recall      : 0.9626
# Macro F1-score    : 0.9593
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           F0       1.00      1.00      1.00       423
#           F1       0.95      0.98      0.97       172
#           F2       0.92      0.96      0.94       158
#           F3       0.93      0.92      0.93       171
#           F4       0.98      0.95      0.97       340
#
#     accuracy                           0.97      1264
#    macro avg       0.96      0.96      0.96      1264
# weighted avg       0.97      0.97      0.97      1264
# Final evaluation completed on best model.
